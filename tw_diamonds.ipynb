# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
bling = pd.read_csv('/diamonds.csv')
diamonds = bling.copy()

# %% [markdown]
# Imported Pandas, Numpy, Matpotlib, and Seaborn
# Made a copy of original dataframe and named it Diamonds

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # New Section

# %%
diamonds = bling.copy()
diamonds.shape
# Out:
# (53940, 11)

# %% [markdown]
# Used the shape attribue to show how much data was in my dataframe.
# There was 53,940 rows and 11 columns

# %%
diamonds.head(10)
# Out:
#    Unnamed: 0  carat        cut color clarity  ...  table  price     x     y     z
# 0           1   0.23      Ideal     E     SI2  ...   55.0    326  3.95  3.98  2.43
# 1           2   0.21    Premium     E     SI1  ...   61.0    326  3.89  3.84  2.31
# 2           3   0.23       Good     E     VS1  ...   65.0    327  4.05  4.07  2.31
# 3           4   0.29    Premium     I     VS2  ...   58.0    334  4.20  4.23  2.63
# 4           5   0.31       Good     J     SI2  ...   58.0    335  4.34  4.35  2.75
# 5           6   0.24  Very Good     J    VVS2  ...   57.0    336  3.94  3.96  2.48
# 6           7   0.24  Very Good     I    VVS1  ...   57.0    336  3.95  3.98  2.47
# 7           8   0.26  Very Good     H     SI1  ...   55.0    337  4.07  4.11  2.53
# 8           9   0.22       Fair     E     VS2  ...   61.0    337  3.87  3.78  2.49
# 9          10   0.23  Very Good     H     VS1  ...   61.0    338  4.00  4.05  2.39
#
# [10 rows x 11 columns]

# %% [markdown]
# I printed my first 10 rows to familiarize myself with the data

# %%
df.rename(columns={'x' : 'length', 'y' : 'width', 'z' : 'depth'})
# Out:
#        Unnamed: 0  carat        cut color  ... price  length  width  depth
# 0               1   0.23      Ideal     E  ...   326    3.95   3.98   2.43
# 1               2   0.21    Premium     E  ...   326    3.89   3.84   2.31
# 2               3   0.23       Good     E  ...   327    4.05   4.07   2.31
# 3               4   0.29    Premium     I  ...   334    4.20   4.23   2.63
# 4               5   0.31       Good     J  ...   335    4.34   4.35   2.75
# ...           ...    ...        ...   ...  ...   ...     ...    ...    ...
# 53935       53936   0.72      Ideal     D  ...  2757    5.75   5.76   3.50
# 53936       53937   0.72       Good     D  ...  2757    5.69   5.75   3.61
# 53937       53938   0.70  Very Good     D  ...  2757    5.66   5.68   3.56
# 53938       53939   0.86    Premium     H  ...  2757    6.15   6.12   3.74
# 53939       53940   0.75      Ideal     D  ...  2757    5.83   5.87   3.64
#
# [53940 rows x 11 columns]

# %% [markdown]
# Originally, I had columns named x, y, and z which represented the diamonds length, width, and depth. I then renamed the columns x, y, and z to length, width, and depth.

# %%
diamonds.cut.value_counts().plot(kind='pie', colormap = 'prism', figsize=(10,10));

# %% [markdown]
# This is a pie chart of the different kind of diamond cuts. They are listed as Ideal (best), Premium, Very Good, Good, and Fair (worst).
# I changed the colors of the pie chart to "prism" using www.matplotlib.org.

# %%
diamonds.clarity.value_counts(ascending=False)
# Out:
# SI1     13065
# VS2     12258
# SI2      9194
# VS1      8171
# VVS2     5066
# VVS1     3655
# IF       1790
# I1        741
# Name: clarity, dtype: int64

# %% [markdown]
# From my diamonds dataframe, I only wanted to see how many flawless (IF) diamonds I had.

# %%
IF = diamonds[diamonds.clarity == 'IF']
IF.shape
# Out:
# (1790, 11)

# %% [markdown]
# I created the new dataframe with only the best diamond clarity known as IF.

# %%
sns.set(style="white")

# %%
sns.relplot(x='carat', y='price', size=5,
            sizes=(40, 100), alpha=.5, palette="muted",
            height=6, data=bling);

# %%
sns.countplot(x="clarity", data=diamonds, hue='price');
